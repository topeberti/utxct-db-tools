# %% [markdown]
# # Get a table and its parent information linked

# %% [markdown]
# ## imports

# %%
import psycopg2
import numpy as np
#import a folder in the parent directory
import sys
sys.path.append('../')
import dbtools.dbtools as qrs
from pathlib import Path
import tifffile as tiff
import os
from tqdm import tqdm

# %% [markdown]
# ## Connection

# %%
try:
    # Connect to the PostgreSQL database
    conn = qrs.connect()
    print("Connected to the database")

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connected to the database

# %% [markdown]
# ## Table info

# %%
table_name = 'measurements'

parent_table_name = 'measurementtypes'

# %%
data = qrs.data_parent(table_name, parent_table_name)

data
# Out:
#     id_measurement                              file_path_measurement  \
# 0               93  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 1               94  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 2               95  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 3               96  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 4               97  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 5               98  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 6               99  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 7              100  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 8              101  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 9              102  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 10             103  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 11             104  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 12             105  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 13             106  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 14             107  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 15             108  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 16             109  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 17             110  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 18             111  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 19             113  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 20             115  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 21             116  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 22             117  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 23             118  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 24             119  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 25             120  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 26             122  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 27             123  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 28             124  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
# 29             121  \\192.168.10.106\imdea\DataDriven_UT_AlbertoVi...
#
#     parent_measurement_id_measurement height_measurement width_measurement  \
# 0                                 NaN       448 cardinal      190 cardinal
# 1                                93.0       505 cardinal      120 cardinal
# 2                                93.0       505 cardinal      120 cardinal
# 3                                93.0       505 cardinal      120 cardinal
# 4                                93.0       505 cardinal      117 cardinal
# 5                                93.0       505 cardinal      117 cardinal
# 6                                93.0       505 cardinal      117 cardinal
# 7                                93.0       505 cardinal      118 cardinal
# 8                                 NaN      3737 cardinal     1770 cardinal
# 9                               101.0      3224 cardinal     1770 cardinal
# 10                                NaN      3735 cardinal     1734 cardinal
# 11                              103.0      3226 cardinal     1734 cardinal
# 12                              102.0      3224 cardinal     1610 cardinal
# 13                              105.0      3224 cardinal     1610 cardinal
# 14                              106.0       203 cardinal     3226 cardinal
# 15                              102.0      3224 cardinal     1629 cardinal
# 16                              108.0      3224 cardinal     1629 cardinal
# 17                              109.0       192 cardinal     3226 cardinal
# 18                              102.0      3224 cardinal     1685 cardinal
# 19                              102.0      3224 cardinal     1664 cardinal
# 20                              104.0      3226 cardinal     1579 cardinal
# 21                              115.0       205 cardinal     3227 cardinal
# 22                              104.0      3226 cardinal     1628 cardinal
# 23                              117.0       203 cardinal     3228 cardinal
# 24                              104.0      3226 cardinal     1626 cardinal
# 25                              119.0       200 cardinal     3227 cardinal
# 26                              111.0       196 cardinal     3227 cardinal
# 27                                NaN       448 cardinal      250 cardinal
# 28                                NaN       448 cardinal      271 cardinal
# 29                              113.0       202 cardinal     3228 cardinal
#
#    depth_measurement dtype_measurement file_type_measurement  \
# 0       492 cardinal     uint8 nominal          .tif nominal
# 1        45 cardinal     uint8 nominal          .tif nominal
# 2        49 cardinal     uint8 nominal          .tif nominal
# 3        48 cardinal     uint8 nominal          .tif nominal
# 4        53 cardinal     uint8 nominal          .tif nominal
# 5        49 cardinal     uint8 nominal          .tif nominal
# 6        51 cardinal     uint8 nominal          .tif nominal
# 7        49 cardinal     uint8 nominal          .tif nominal
# 8      1015 cardinal     uint16 string         folder string
# 9      1015 cardinal      uint8 string         folder string
# 10     1003 cardinal     uint16 string         folder string
# 11     1003 cardinal      uint8 string         folder string
# 12      240 cardinal      uint8 string         folder string
# 13      240 cardinal      uint8 string         folder string
# 14     1609 cardinal      uint8 string           .tif string
# 15      239 cardinal      uint8 string         folder string
# 16      239 cardinal      uint8 string         folder string
# 17     1628 cardinal      uint8 string           .tif string
# 18      245 cardinal      uint8 string         folder string
# 19      284 cardinal      uint8 string         folder string
# 20      258 cardinal      uint8 string         folder string
# 21     1579 cardinal      uint8 string           .tif string
# 22      248 cardinal      uint8 string         folder string
# 23     1599 cardinal      uint8 string           .tif string
# 24      250 cardinal      uint8 string         folder string
# 25     1593 cardinal      uint8 string           .tif string
# 26     1685 cardinal      uint8 string           .tif string
# 27      424 cardinal     uint8 nominal          .tif nominal
# 28      428 cardinal     uint8 nominal          .tif nominal
# 29     1660 cardinal      uint8 string           .tif string
#
#    signal_type_measurement axes_order_measurement  ...  \
# 0               RF nominal   ['z', 'y', 'x'] list  ...
# 1               RF nominal   ['z', 'y', 'x'] list  ...
# 2               RF nominal   ['z', 'y', 'x'] list  ...
# 3               RF nominal   ['z', 'y', 'x'] list  ...
# 4               RF nominal   ['z', 'y', 'x'] list  ...
# 5               RF nominal   ['z', 'y', 'x'] list  ...
# 6               RF nominal   ['z', 'y', 'x'] list  ...
# 7               RF nominal   ['z', 'y', 'x'] list  ...
# 8                      NaN   ['x', 'y', 'z'] list  ...
# 9                      NaN   ['x', 'y', 'z'] list  ...
# 10                     NaN   ['x', 'y', 'z'] list  ...
# 11                     NaN   ['x', 'y', 'z'] list  ...
# 12                     NaN   ['x', 'y', 'z'] list  ...
# 13                     NaN   ['x', 'y', 'z'] list  ...
# 14                     NaN   ['z', 'y', 'x'] list  ...
# 15                     NaN   ['x', 'y', 'z'] list  ...
# 16                     NaN   ['x', 'y', 'z'] list  ...
# 17                     NaN   ['z', 'y', 'x'] list  ...
# 18                     NaN   ['x', 'y', 'z'] list  ...
# 19                     NaN   ['x', 'y', 'z'] list  ...
# 20                     NaN   ['x', 'y', 'z'] list  ...
# 21                     NaN   ['z', 'y', 'x'] list  ...
# 22                     NaN   ['x', 'y', 'z'] list  ...
# 23                     NaN   ['z', 'y', 'x'] list  ...
# 24                     NaN   ['x', 'y', 'z'] list  ...
# 25                     NaN   ['z', 'y', 'x'] list  ...
# 26                     NaN   ['z', 'y', 'x'] list  ...
# 27              RF nominal   ['z', 'y', 'x'] list  ...
# 28              RF nominal   ['z', 'y', 'x'] list  ...
# 29                     NaN   ['z', 'y', 'x'] list  ...
#
#    current_measurementtype voxel_size_measurementtype  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 6                      NaN                        NaN
# 7                      NaN                        NaN
# 8                    90 uA                   0.025 mm
# 9                    90 uA                   0.025 mm
# 10                   90 uA                   0.025 mm
# 11                   90 uA                   0.025 mm
# 12                   90 uA                   0.025 mm
# 13                   90 uA                   0.025 mm
# 14                   90 uA                   0.025 mm
# 15                   90 uA                   0.025 mm
# 16                   90 uA                   0.025 mm
# 17                   90 uA                   0.025 mm
# 18                   90 uA                   0.025 mm
# 19                   90 uA                   0.025 mm
# 20                   90 uA                   0.025 mm
# 21                   90 uA                   0.025 mm
# 22                   90 uA                   0.025 mm
# 23                   90 uA                   0.025 mm
# 24                   90 uA                   0.025 mm
# 25                   90 uA                   0.025 mm
# 26                   90 uA                   0.025 mm
# 27                     NaN                        NaN
# 28                     NaN                        NaN
# 29                   90 uA                   0.025 mm
#
#    images_taken_per_projection_measurementtype  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                   5 cardinal
# 9                                   5 cardinal
# 10                                  5 cardinal
# 11                                  5 cardinal
# 12                                  5 cardinal
# 13                                  5 cardinal
# 14                                  5 cardinal
# 15                                  5 cardinal
# 16                                  5 cardinal
# 17                                  5 cardinal
# 18                                  5 cardinal
# 19                                  5 cardinal
# 20                                  5 cardinal
# 21                                  5 cardinal
# 22                                  5 cardinal
# 23                                  5 cardinal
# 24                                  5 cardinal
# 25                                  5 cardinal
# 26                                  5 cardinal
# 27                                         NaN
# 28                                         NaN
# 29                                  5 cardinal
#
#     exposure_time_per_image_taken_measurementtype binning_measurementtype  \
# 0                                             NaN                     NaN
# 1                                             NaN                     NaN
# 2                                             NaN                     NaN
# 3                                             NaN                     NaN
# 4                                             NaN                     NaN
# 5                                             NaN                     NaN
# 6                                             NaN                     NaN
# 7                                             NaN                     NaN
# 8                                           0.2 s              1 cardinal
# 9                                           0.2 s              1 cardinal
# 10                                          0.2 s              1 cardinal
# 11                                          0.2 s              1 cardinal
# 12                                          0.2 s              1 cardinal
# 13                                          0.2 s              1 cardinal
# 14                                          0.2 s              1 cardinal
# 15                                          0.2 s              1 cardinal
# 16                                          0.2 s              1 cardinal
# 17                                          0.2 s              1 cardinal
# 18                                          0.2 s              1 cardinal
# 19                                          0.2 s              1 cardinal
# 20                                          0.2 s              1 cardinal
# 21                                          0.2 s              1 cardinal
# 22                                          0.2 s              1 cardinal
# 23                                          0.2 s              1 cardinal
# 24                                          0.2 s              1 cardinal
# 25                                          0.2 s              1 cardinal
# 26                                          0.2 s              1 cardinal
# 27                                            NaN                     NaN
# 28                                            NaN                     NaN
# 29                                          0.2 s              1 cardinal
#
#    projections_measurementtype target_measurementtype filter_measurementtype  \
# 0                          NaN                    NaN                    NaN
# 1                          NaN                    NaN                    NaN
# 2                          NaN                    NaN                    NaN
# 3                          NaN                    NaN                    NaN
# 4                          NaN                    NaN                    NaN
# 5                          NaN                    NaN                    NaN
# 6                          NaN                    NaN                    NaN
# 7                          NaN                    NaN                    NaN
# 8                3738 cardinal      wolframio nominal            LE1 nominal
# 9                3738 cardinal      wolframio nominal            LE1 nominal
# 10               3738 cardinal      wolframio nominal            LE1 nominal
# 11               3738 cardinal      wolframio nominal            LE1 nominal
# 12               3738 cardinal      wolframio nominal            LE1 nominal
# 13               3738 cardinal      wolframio nominal            LE1 nominal
# 14               3738 cardinal      wolframio nominal            LE1 nominal
# 15               3738 cardinal      wolframio nominal            LE1 nominal
# 16               3738 cardinal      wolframio nominal            LE1 nominal
# 17               3738 cardinal      wolframio nominal            LE1 nominal
# 18               3738 cardinal      wolframio nominal            LE1 nominal
# 19               3738 cardinal      wolframio nominal            LE1 nominal
# 20               3738 cardinal      wolframio nominal            LE1 nominal
# 21               3738 cardinal      wolframio nominal            LE1 nominal
# 22               3738 cardinal      wolframio nominal            LE1 nominal
# 23               3738 cardinal      wolframio nominal            LE1 nominal
# 24               3738 cardinal      wolframio nominal            LE1 nominal
# 25               3738 cardinal      wolframio nominal            LE1 nominal
# 26               3738 cardinal      wolframio nominal            LE1 nominal
# 27                         NaN                    NaN                    NaN
# 28                         NaN                    NaN                    NaN
# 29               3738 cardinal      wolframio nominal            LE1 nominal
#
#    Detector_measurementtype                                DAC_measurementtype
# 0                       NaN                                                NaN
# 1                       NaN                                                NaN
# 2                       NaN                                                NaN
# 3                       NaN                                                NaN
# 4                       NaN                                                NaN
# 5                       NaN                                                NaN
# 6                       NaN                                                NaN
# 7                       NaN                                                NaN
# 8        Flat Panel nominal                                                NaN
# 9        Flat Panel nominal                                                NaN
# 10       Flat Panel nominal                                                NaN
# 11       Flat Panel nominal                                                NaN
# 12       Flat Panel nominal                                                NaN
# 13       Flat Panel nominal                                                NaN
# 14       Flat Panel nominal                                                NaN
# 15       Flat Panel nominal                                                NaN
# 16       Flat Panel nominal                                                NaN
# 17       Flat Panel nominal                                                NaN
# 18       Flat Panel nominal                                                NaN
# 19       Flat Panel nominal                                                NaN
# 20       Flat Panel nominal                                                NaN
# 21       Flat Panel nominal                                                NaN
# 22       Flat Panel nominal                                                NaN
# 23       Flat Panel nominal                                                NaN
# 24       Flat Panel nominal                                                NaN
# 25       Flat Panel nominal                                                NaN
# 26       Flat Panel nominal                                                NaN
# 27                      NaN  [[10.1,4.33],[12.1,6.18],[19.7,10.38],[26.7,15...
# 28                      NaN  [[10.1,4.33],[12.1,6.18],[19.7,10.38],[26.7,15...
# 29       Flat Panel nominal                                                NaN
#
# [30 rows x 42 columns]
