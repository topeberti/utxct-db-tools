# %% [markdown]
# # Get a table and its parent information linked

# %% [markdown]
# ## imports

# %%
import psycopg2
import numpy as np
#import a folder in the parent directory
import sys
sys.path.append('../')
import dbtools.dbtools as qrs
from pathlib import Path
import tifffile as tiff
import os
from tqdm import tqdm

# %% [markdown]
# ## Connection

# %%
try:
    # Connect to the PostgreSQL database
    conn = qrs.connect()
    print("Connected to the database")

except (Exception, psycopg2.DatabaseError) as error:
    print(error)
# Out:
# Connected to the database

# %% [markdown]
# ## Table info

# %%
table_name = 'panels'

parent_table_name = 'fabrications'

# %%
data = qrs.data_parent(table_name, parent_table_name)

data
# Out:
#    id_panel                name_panel  material_id_panel  \
# 0         3  Juan_Ignacio_placeholder                 15
# 1         4   Pegaso Piramide 7922843                 16
# 2         5                     Na_01                 16
# 3         6                     Na_02                 16
# 4         7                     Na_03                 16
# 5         8                     Na_04                 16
# 6         9                     Na_05                 16
# 7        10                   Name_06                 16
# 8        11                     Na_07                 16
# 9        12                     Na_08                 16
#
#                                    description_panel height_panel width_panel  \
# 0  This is a placeholder because we dont know fro...       1.0 mm      1.0 mm
# 1  The panel features multiple height levels rang...     945.0 mm   1150.0 mm
# 2                                               None     200.0 mm    200.0 mm
# 3                                               None     200.0 mm    200.0 mm
# 4                                               None     200.0 mm    200.0 mm
# 5                                               None     200.0 mm    200.0 mm
# 6                                               None     200.0 mm    200.0 mm
# 7                                               None     200.0 mm    200.0 mm
# 8                                               None     200.0 mm    200.0 mm
# 9                                               None     200.0 mm    200.0 mm
#
#   thickness_panel edges_cutted_panel  \
# 0          1.0 mm          True bool
# 1          5.0 mm          True bool
# 2          5.0 mm          True bool
# 3          5.0 mm          True bool
# 4          5.0 mm         False bool
# 5          5.0 mm         False bool
# 6          5.0 mm          True bool
# 7          5.0 mm          True bool
# 8          5.0 mm          True bool
# 9          5.0 mm          True bool
#
#                                   layer_layout_panel          geometry_panel  \
# 0  [-45, 90, 45, 0, -45, 90, 45, 0, 0, 45, 90, -4...  Paralell faces nominal
# 1     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list         pyramid nominal
# 2     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 3     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 4     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 5     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 6     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 7     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 8     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
# 9     [45, -45, 90, 0, 45, -45, 0, 90, -45, 45] list  parallel faces nominal
#
#    id_fabrication      name_fabrication hand_lay_up_fabrication  \
# 0               2          Juan_Ignacio            True boolean
# 1               3    AIRBUS placeholder                     NaN
# 2               4  Nacho_simple_cycle_1               True bool
# 3               5  Nacho_simple_cycle_2               True bool
# 4               6  Nacho_simple_cycle_3               True bool
# 5               7  Nacho_simple_cycle_4               True bool
# 6               8  Nacho_simple_cycle_5               True bool
# 7               9  Nacho_simple_cycle_6               True bool
# 8              10  Nacho_simple_cycle_7               True bool
# 9              11  Nacho_simple_cycle_8               True bool
#
#   vacuum_bag_fabrication autoclave_fabrication pressure_fabrication  \
# 0           True boolean         False boolean                  NaN
# 1                    NaN                   NaN                  NaN
# 2                    NaN                   NaN             1.75 bar
# 3                    NaN                   NaN             0.75 bar
# 4                    NaN                   NaN                7 bar
# 5                    NaN                   NaN              4.5 bar
# 6                    NaN                   NaN                7 bar
# 7                    NaN                   NaN              4.5 bar
# 8                    NaN                   NaN             1.75 bar
# 9                    NaN                   NaN                7 bar
#
#                         temperature_ramp_fabrication
# 0                                                NaN
# 1                                                NaN
# 2  10 °C/min to 180 °C – 2 h dwell – 2.5 °C/min c...
# 3  10 °C/min to 180 °C – 2 h dwell – 2.5 °C/min c...
# 4  10 °C/min to 180 °C – 2 h dwell – 2.5 °C/min c...
# 5  10 °C/min to 180 °C – 2 h dwell – 2.5 °C/min c...
# 6  6 °C/min to 180 °C – 2 h dwell – 2.5 °C/min co...
# 7  6 °C/min to 180 °C – 2 h dwell – 2.5 °C/min co...
# 8  6 °C/min to 180 °C – 2 h dwell – 2.5 °C/min co...
# 9  2 °C/min to 180 °C – 2 h dwell – 2.5 °C/min co...
